# %%
import swap_planner as s

# %% [markdown]
# ## Planowanie dla baterii do fabryki

# %%
# Sprawdzenie czy w horyzoncie cyklu da się wyznaczyć od jego początku kolejne wymiany
# jedna za drugą od robota najbardziej rozładowanego tak, żeby żaden z robotów nie 
# rozładował się.(powinien być błąd)
s.FULL_BATTERY_WORKING_TIME = 4*60 # [min]
s.SWAP_TIME = 40 # [min]
s.STANDARD_CYCLE_TIME = s.FULL_BATTERY_WORKING_TIME - 10 # [min] standardowy czas na jaki planowane są wymiany
s.ALLOWED_CYCLE_TIME = s.FULL_BATTERY_WORKING_TIME - 5 # [min] pozwala na dłuższą pracę na baterii i wykonanie
# późniejszej wymiany, aby ustabilizować wymiany w równych odstępach czasowych

robots = [{"id": "r1",  "time_to_discharged": 30}, 
          {"id": "r2",  "time_to_discharged": 50},
          {"id": "r3",  "time_to_discharged": 70}, 
          {"id": "r4",  "time_to_discharged": 200},
          {"id": "r5",  "time_to_discharged": 230}]


planner = s.SwapPlanner("test_name", robots)
planner.is_possible_create_init_cycle()
# Out:
# Roboty nie zdążą wymienić baterii w trakcie rozruchu wymian przed wejściem w regularny cykl.
# False

# %%
# Sprawdzany jest łączny czas wymian jaki może pojawić się w regularnym
# cyklu w odniesieniu do czasu cyklu. (powinien być błąd)
s.FULL_BATTERY_WORKING_TIME = 4*60 # [min]
s.SWAP_TIME = 22 # [min]
s.STANDARD_CYCLE_TIME = s.FULL_BATTERY_WORKING_TIME - 100 # [min] standardowy czas na jaki planowane są wymiany
s.ALLOWED_CYCLE_TIME = s.FULL_BATTERY_WORKING_TIME - 5 # [min] pozwala na dłuższą pracę na baterii i wykonanie
# późniejszej wymiany, aby ustabilizować wymiany w równych odstępach czasowych

robots = [{"id": "r1",  "time_to_discharged": 40}, 
          {"id": "r2",  "time_to_discharged": 100},
          {"id": "r3",  "time_to_discharged": 140}, 
          {"id": "r4",  "time_to_discharged": 200},
          {"id": "r5",  "time_to_discharged": 220},
          {"id": "r6",  "time_to_discharged": 230},
          {"id": "r7",  "time_to_discharged": 235}]


planner = s.SwapPlanner("test_name", robots)
planner.is_possible_create_init_cycle()
# Out:
# Wymiany trwają dłużej niż standardowy czas cyklu. Czas wymian: 154, czas cyklu: 140
# False

# %%
s.FULL_BATTERY_WORKING_TIME = 4*60 # [min]
s.SWAP_TIME = 40 # [min]
s.STANDARD_CYCLE_TIME = s.FULL_BATTERY_WORKING_TIME - 10 # [min] standardowy czas na jaki planowane są wymiany
s.ALLOWED_CYCLE_TIME = s.FULL_BATTERY_WORKING_TIME - 5 # [min] pozwala na dłuższą pracę na baterii i wykonanie
# późniejszej wymiany, aby ustabilizować wymiany w równych odstępach czasowych

robots = [{"id": "r1",  "time_to_discharged": 60}, 
          {"id": "r2",  "time_to_discharged": 100},
          {"id": "r3",  "time_to_discharged": 140}, 
          {"id": "r4",  "time_to_discharged": 200},
          {"id": "r5",  "time_to_discharged": 230}]


planner = s.SwapPlanner("test_name", robots)
planner.is_possible_create_init_cycle()
planner.create_plan(2000)

print("valid plan: {}".format(planner.is_valid_plan()))
planner.create_swap_gant()
planner.create_robots_swap_gant()
planner.create_next_swaps_diff()
# Out:
# valid plan: True

# %%
s.FULL_BATTERY_WORKING_TIME = 4*60 # [min]
s.SWAP_TIME = 3 # [min]
s.STANDARD_CYCLE_TIME = s.FULL_BATTERY_WORKING_TIME - 20 # [min] standardowy czas na jaki planowane są wymiany
s.ALLOWED_CYCLE_TIME = s.FULL_BATTERY_WORKING_TIME - 5 # [min] pozwala na dłuższą pracę na baterii i wykonanie
# późniejszej wymiany, aby ustabilizować wymiany w równych odstępach czasowych

robots = [{"id": "r1",  "time_to_discharged": 20}, 
          {"id": "r2",  "time_to_discharged": 60},
          {"id": "r3",  "time_to_discharged": 140}, 
          {"id": "r4",  "time_to_discharged": 200},
          {"id": "r5",  "time_to_discharged": 230}]

planner = s.SwapPlanner("test_name", robots)
planner.is_possible_create_init_cycle()
planner.create_plan(1000)

print("valid plan: {}".format(planner.is_valid_plan()))
planner.create_swap_gant()
planner.create_robots_swap_gant()
planner.create_next_swaps_diff()
# Out:
# valid plan: True

# %%
s.FULL_BATTERY_WORKING_TIME = 4*60 # [min]
s.SWAP_TIME = 40 # [min]
s.STANDARD_CYCLE_TIME = s.FULL_BATTERY_WORKING_TIME - 10 # [min] standardowy czas na jaki planowane są wymiany
s.ALLOWED_CYCLE_TIME = s.FULL_BATTERY_WORKING_TIME - 5 # [min] pozwala na dłuższą pracę na baterii i wykonanie
# późniejszej wymiany, aby ustabilizować wymiany w równych odstępach czasowych

robots = [{"id": "r1",  "time_to_discharged": s.FULL_BATTERY_WORKING_TIME}, 
          {"id": "r2",  "time_to_discharged": s.FULL_BATTERY_WORKING_TIME},
          {"id": "r3",  "time_to_discharged": s.FULL_BATTERY_WORKING_TIME}, 
          {"id": "r4",  "time_to_discharged": s.FULL_BATTERY_WORKING_TIME},
          {"id": "r5",  "time_to_discharged": s.FULL_BATTERY_WORKING_TIME}]

planner = s.SwapPlanner("test_name", robots)
planner.is_possible_create_init_cycle()
planner.create_plan(1000)

print("valid plan: {}".format(planner.is_valid_plan()))
planner.create_swap_gant()
planner.create_robots_swap_gant()
planner.create_next_swaps_diff()
# Out:
# valid plan: True

# %%
s.FULL_BATTERY_WORKING_TIME = 4*60 # [min]
s.SWAP_TIME = 3 # [min]
s.STANDARD_CYCLE_TIME = s.FULL_BATTERY_WORKING_TIME - 10 # [min] standardowy czas na jaki planowane są wymiany
s.ALLOWED_CYCLE_TIME = s.FULL_BATTERY_WORKING_TIME - 5 # [min] pozwala na dłuższą pracę na baterii i wykonanie
# późniejszej wymiany, aby ustabilizować wymiany w równych odstępach czasowych

robots = [{"id": "r1",  "time_to_discharged": s.FULL_BATTERY_WORKING_TIME}, 
          {"id": "r2",  "time_to_discharged": s.FULL_BATTERY_WORKING_TIME},
          {"id": "r3",  "time_to_discharged": s.FULL_BATTERY_WORKING_TIME}, 
          {"id": "r4",  "time_to_discharged": s.FULL_BATTERY_WORKING_TIME},
          {"id": "r5",  "time_to_discharged": s.FULL_BATTERY_WORKING_TIME}]

planner = s.SwapPlanner("test_name", robots)
planner.is_possible_create_init_cycle()
planner.create_plan(2000)

print("valid plan: {}".format(planner.is_valid_plan()))
planner.create_swap_gant()
planner.create_robots_swap_gant()
planner.create_next_swaps_diff()
# Out:
# valid plan: True

# %% [markdown]
# ## Planownaie dla baterii dla dronów

# %%
s.FULL_BATTERY_WORKING_TIME = 15 # [min]
s.SWAP_TIME = 3 # [min]
s.STANDARD_CYCLE_TIME = s.FULL_BATTERY_WORKING_TIME - 2 # [min] standardowy czas na jaki planowane są wymiany
s.ALLOWED_CYCLE_TIME = s.FULL_BATTERY_WORKING_TIME - 1 # [min] pozwala na dłuższą pracę na baterii i wykonanie
# późniejszej wymiany, aby ustabilizować wymiany w równych odstępach czasowych

robots = [{"id": "r1",  "time_to_discharged": 3}, 
          {"id": "r2",  "time_to_discharged": 6},
          {"id": "r3",  "time_to_discharged": 1}, 
          {"id": "r4",  "time_to_discharged": 9}]


planner = s.SwapPlanner("test_name", robots)
planner.is_possible_create_init_cycle()
planner.create_plan(240)

print("valid plan: {}".format(planner.is_valid_plan()))
planner.create_swap_gant()
planner.create_robots_swap_gant()
planner.create_next_swaps_diff()
# Out:
# valid plan: True

# %%
s.FULL_BATTERY_WORKING_TIME = 15 # [min]
s.SWAP_TIME = 3 # [min]
s.STANDARD_CYCLE_TIME = s.FULL_BATTERY_WORKING_TIME - 2 # [min] standardowy czas na jaki planowane są wymiany
s.ALLOWED_CYCLE_TIME = s.FULL_BATTERY_WORKING_TIME - 1 # [min] pozwala na dłuższą pracę na baterii i wykonanie
# późniejszej wymiany, aby ustabilizować wymiany w równych odstępach czasowych

robots = [{"id": "r1",  "time_to_discharged": 4}, 
          {"id": "r2",  "time_to_discharged": 6},
          {"id": "r3",  "time_to_discharged": 2}, 
          {"id": "r4",  "time_to_discharged": 9}]


planner = s.SwapPlanner("test_name", robots)
planner.is_possible_create_init_cycle()
planner.create_plan(240)

print("valid plan: {}".format(planner.is_valid_plan()))
planner.create_swap_gant()
planner.create_robots_swap_gant()
planner.create_next_swaps_diff()
# Out:
# valid plan: True

# %%
s.FULL_BATTERY_WORKING_TIME = 15 # [min]
s.SWAP_TIME = 1 # [min]
s.STANDARD_CYCLE_TIME = s.FULL_BATTERY_WORKING_TIME - 2 # [min] standardowy czas na jaki planowane są wymiany
s.ALLOWED_CYCLE_TIME = s.FULL_BATTERY_WORKING_TIME - 1 # [min] pozwala na dłuższą pracę na baterii i wykonanie
# późniejszej wymiany, aby ustabilizować wymiany w równych odstępach czasowych

robots = [{"id": "r1",  "time_to_discharged": 4}, 
          {"id": "r2",  "time_to_discharged": 6},
          {"id": "r3",  "time_to_discharged": 2}, 
          {"id": "r4",  "time_to_discharged": 9}]


planner = s.SwapPlanner("test_name", robots)
planner.is_possible_create_init_cycle()
planner.create_plan(240)

print("valid plan: {}".format(planner.is_valid_plan()))
planner.create_swap_gant()
planner.create_robots_swap_gant()
planner.create_next_swaps_diff()
# Out:
# valid plan: True
