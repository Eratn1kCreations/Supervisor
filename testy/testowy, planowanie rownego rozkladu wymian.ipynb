# %%
import swap_planner as s
import datetime
log_folder_name = "test_name"

# %% [markdown]
# ## Planowanie dla baterii do fabryki

# %%
# Sprawdzenie czy w horyzoncie cyklu da się wyznaczyć od jego początku kolejne wymiany
# jedna za drugą od robota najbardziej rozładowanego tak, żeby żaden z robotów nie 
# rozładował się.(powinien być błąd)
s.FULL_BATTERY_WORKING_TIME = 4*60 # [min]
s.SWAP_TIME = 40 # [min]
s.STANDARD_CYCLE_TIME = s.FULL_BATTERY_WORKING_TIME - 10 # [min] standardowy czas na jaki planowane są wymiany
s.ALLOWED_CYCLE_TIME = s.FULL_BATTERY_WORKING_TIME - 5 # [min] pozwala na dłuższą pracę na baterii i wykonanie
# późniejszej wymiany, aby ustabilizować wymiany w równych odstępach czasowych

robots = [{"id": "r1",  "time_to_discharged": 30, "swap": None}, 
          {"id": "r2",  "time_to_discharged": 50, "swap": None},
          {"id": "r3",  "time_to_discharged": 70, "swap": None}, 
          {"id": "r4",  "time_to_discharged": 200, "swap": None},
          {"id": "r5",  "time_to_discharged": 230, "swap": None}]

ref_time =  datetime.datetime.strptime("2021-05-27 17:29:18", "%Y-%m-%d %H:%M:%S")
s.is_possible_create_first_cycle(robots, ref_time)
# Out:
# Roboty rozładują się zanim nastąpi wymiana
# False

# %%
# Sprawdzany jest łączny czas wymian jaki może pojawić się w regularnym
# cyklu w odniesieniu do czasu cyklu. (powinien być błąd)
s.FULL_BATTERY_WORKING_TIME = 4*60 # [min]
s.SWAP_TIME = 22 # [min]
s.STANDARD_CYCLE_TIME = s.FULL_BATTERY_WORKING_TIME - 100 # [min] standardowy czas na jaki planowane są wymiany
s.ALLOWED_CYCLE_TIME = s.FULL_BATTERY_WORKING_TIME - 5 # [min] pozwala na dłuższą pracę na baterii i wykonanie
# późniejszej wymiany, aby ustabilizować wymiany w równych odstępach czasowych

robots = [{"id": "r1",  "time_to_discharged": 40, "swap": None}, 
          {"id": "r2",  "time_to_discharged": 100, "swap": None},
          {"id": "r3",  "time_to_discharged": 140, "swap": None}, 
          {"id": "r4",  "time_to_discharged": 200, "swap": None},
          {"id": "r5",  "time_to_discharged": 220, "swap": None},
          {"id": "r6",  "time_to_discharged": 230, "swap": None},
          {"id": "r7",  "time_to_discharged": 235, "swap": None}]

ref_time =  datetime.datetime.strptime("2021-05-27 17:29:18", "%Y-%m-%d %H:%M:%S")
s.is_possible_create_first_cycle(robots, ref_time)
# Out:
# Wymiany trwają dłużej niż standardowy czas cyklu. Czas wymian: 154, czas cyklu: 140
# False

# %%
# plan ok
s.FULL_BATTERY_WORKING_TIME = 4*60 # [min]
s.SWAP_TIME = 30 # [min]
s.STANDARD_CYCLE_TIME = s.FULL_BATTERY_WORKING_TIME - 10 # [min] standardowy czas na jaki planowane są wymiany
s.ALLOWED_CYCLE_TIME = s.FULL_BATTERY_WORKING_TIME - 5 # [min] pozwala na dłuższą pracę na baterii i wykonanie
# późniejszej wymiany, aby ustabilizować wymiany w równych odstępach czasowych

robots = [{"id": "r1",  "time_to_discharged": 60, "swap": None}, 
          {"id": "r2",  "time_to_discharged": 100, "swap": None},
          {"id": "r3",  "time_to_discharged": 140, "swap": None}, 
          {"id": "r4",  "time_to_discharged": 200, "swap": None},
          {"id": "r5",  "time_to_discharged": 230, "swap": None}]

ref_time =  datetime.datetime.strptime("2021-05-27 17:29:18", "%Y-%m-%d %H:%M:%S")
s.is_possible_create_first_cycle(robots, ref_time)
planner = s.SwapPlanner()
planner.start_swaps_time = ref_time
planner.create_plan(2000, robots)
# planner.create_plan(s.FULL_BATTERY_WORKING_TIME, robots)

print("valid plan: {}".format(planner.is_valid_plan()))
logger = s.SwapLogCreator(planner.plan)
logger.create_swap_gant(log_folder_name)
logger.create_robots_swap_gant(log_folder_name)
logger.create_next_swaps_diff(log_folder_name)
# Out:
# Ułożenie pierwszego cyklu wymian jest możliwe.
# valid plan: True

# %%
# plan ok
s.FULL_BATTERY_WORKING_TIME = 4*60 # [min]
s.SWAP_TIME = 3 # [min]
s.STANDARD_CYCLE_TIME = s.FULL_BATTERY_WORKING_TIME - 20 # [min] standardowy czas na jaki planowane są wymiany
s.ALLOWED_CYCLE_TIME = s.FULL_BATTERY_WORKING_TIME - 5 # [min] pozwala na dłuższą pracę na baterii i wykonanie
# późniejszej wymiany, aby ustabilizować wymiany w równych odstępach czasowych

robots = [{"id": "r1",  "time_to_discharged": 20, "swap": None}, 
          {"id": "r2",  "time_to_discharged": 60, "swap": None},
          {"id": "r3",  "time_to_discharged": 140, "swap": None}, 
          {"id": "r4",  "time_to_discharged": 200, "swap": None},
          {"id": "r5",  "time_to_discharged": 230, "swap": None}]

ref_time =  datetime.datetime.strptime("2021-05-27 17:29:18", "%Y-%m-%d %H:%M:%S")
s.is_possible_create_first_cycle(robots, ref_time)
planner = s.SwapPlanner()
planner.start_swaps_time = ref_time
planner.create_plan(1000, robots)

print("valid plan: {}".format(planner.is_valid_plan()))
logger = s.SwapLogCreator(planner.plan)
logger.create_swap_gant(log_folder_name)
logger.create_robots_swap_gant(log_folder_name)
logger.create_next_swaps_diff(log_folder_name)
# Out:
# Ułożenie pierwszego cyklu wymian jest możliwe.
# valid plan: True

# %%
# plan ok
s.FULL_BATTERY_WORKING_TIME = 4*60 # [min]
s.SWAP_TIME = 40 # [min]
s.STANDARD_CYCLE_TIME = s.FULL_BATTERY_WORKING_TIME - 10 # [min] standardowy czas na jaki planowane są wymiany
s.ALLOWED_CYCLE_TIME = s.FULL_BATTERY_WORKING_TIME - 5 # [min] pozwala na dłuższą pracę na baterii i wykonanie
# późniejszej wymiany, aby ustabilizować wymiany w równych odstępach czasowych

robots = [{"id": "r1",  "time_to_discharged": s.FULL_BATTERY_WORKING_TIME, "swap": None}, 
          {"id": "r2",  "time_to_discharged": s.FULL_BATTERY_WORKING_TIME, "swap": None},
          {"id": "r3",  "time_to_discharged": s.FULL_BATTERY_WORKING_TIME, "swap": None}, 
          {"id": "r4",  "time_to_discharged": s.FULL_BATTERY_WORKING_TIME, "swap": None},
          {"id": "r5",  "time_to_discharged": s.FULL_BATTERY_WORKING_TIME, "swap": None}]

ref_time =  datetime.datetime.strptime("2021-05-27 17:29:18", "%Y-%m-%d %H:%M:%S")
s.is_possible_create_first_cycle(robots, ref_time)
planner = s.SwapPlanner()
planner.start_swaps_time = ref_time
planner.create_plan(1000, robots)

print("valid plan: {}".format(planner.is_valid_plan()))
logger = s.SwapLogCreator(planner.plan)
logger.create_swap_gant(log_folder_name)
logger.create_robots_swap_gant(log_folder_name)
logger.create_next_swaps_diff(log_folder_name)
# Out:
# Ułożenie pierwszego cyklu wymian jest możliwe.
# valid plan: True

# %%
# plan ok
s.FULL_BATTERY_WORKING_TIME = 4*60 # [min]
s.SWAP_TIME = 3 # [min]
s.STANDARD_CYCLE_TIME = s.FULL_BATTERY_WORKING_TIME - 10 # [min] standardowy czas na jaki planowane są wymiany
s.ALLOWED_CYCLE_TIME = s.FULL_BATTERY_WORKING_TIME - 5 # [min] pozwala na dłuższą pracę na baterii i wykonanie
# późniejszej wymiany, aby ustabilizować wymiany w równych odstępach czasowych

robots = [{"id": "r1",  "time_to_discharged": s.FULL_BATTERY_WORKING_TIME, "swap": None}, 
          {"id": "r2",  "time_to_discharged": s.FULL_BATTERY_WORKING_TIME, "swap": None},
          {"id": "r3",  "time_to_discharged": s.FULL_BATTERY_WORKING_TIME, "swap": None}, 
          {"id": "r4",  "time_to_discharged": s.FULL_BATTERY_WORKING_TIME, "swap": None},
          {"id": "r5",  "time_to_discharged": s.FULL_BATTERY_WORKING_TIME, "swap": None}]

ref_time =  datetime.datetime.strptime("2021-05-27 17:29:18", "%Y-%m-%d %H:%M:%S")
s.is_possible_create_first_cycle(robots, ref_time)
planner = s.SwapPlanner()
planner.start_swaps_time = ref_time
planner.create_plan(2000, robots)

print("valid plan: {}".format(planner.is_valid_plan()))
logger = s.SwapLogCreator(planner.plan)
logger.create_swap_gant(log_folder_name)
logger.create_robots_swap_gant(log_folder_name)
logger.create_next_swaps_diff(log_folder_name)
# Out:
# Ułożenie pierwszego cyklu wymian jest możliwe.
# valid plan: True

# %% [markdown]
# ## Planownaie dla baterii dla dronów

# %%
# plan błędny
s.FULL_BATTERY_WORKING_TIME = 15 # [min]
s.SWAP_TIME = 3 # [min]
s.STANDARD_CYCLE_TIME = s.FULL_BATTERY_WORKING_TIME - 2 # [min] standardowy czas na jaki planowane są wymiany
s.ALLOWED_CYCLE_TIME = s.FULL_BATTERY_WORKING_TIME - 1 # [min] pozwala na dłuższą pracę na baterii i wykonanie
# późniejszej wymiany, aby ustabilizować wymiany w równych odstępach czasowych

robots = [{"id": "r1",  "time_to_discharged": 3, "swap": None}, 
          {"id": "r2",  "time_to_discharged": 6, "swap": None},
          {"id": "r3",  "time_to_discharged": 1, "swap": None}, 
          {"id": "r4",  "time_to_discharged": 9, "swap": None}]

ref_time =  datetime.datetime.strptime("2021-05-27 17:29:18", "%Y-%m-%d %H:%M:%S")
s.is_possible_create_first_cycle(robots, ref_time)
planner = s.SwapPlanner()
planner.start_swaps_time = ref_time
planner.create_plan(240, robots)

print("valid plan: {}".format(planner.is_valid_plan()))
logger = s.SwapLogCreator(planner.plan)
logger.create_swap_gant(log_folder_name)
logger.create_robots_swap_gant(log_folder_name)
logger.create_next_swaps_diff(log_folder_name)
# Out:
# Roboty rozładują się zanim nastąpi wymiana
# 1. Wymiany pokrywają się
# start swap time: 2021-05-27 17:31:18, swap time[min]: 3, robot id: r1, active swap: False
# start swap time: 2021-05-27 17:29:18, swap time[min]: 3, robot id: r3, active swap: False
# valid plan: False

# %%
# plan błędny
s.FULL_BATTERY_WORKING_TIME = 15 # [min]
s.SWAP_TIME = 3 # [min]
s.STANDARD_CYCLE_TIME = s.FULL_BATTERY_WORKING_TIME - 2 # [min] standardowy czas na jaki planowane są wymiany
s.ALLOWED_CYCLE_TIME = s.FULL_BATTERY_WORKING_TIME - 1 # [min] pozwala na dłuższą pracę na baterii i wykonanie
# późniejszej wymiany, aby ustabilizować wymiany w równych odstępach czasowych

robots = [{"id": "r1",  "time_to_discharged": 4, "swap": None}, 
          {"id": "r2",  "time_to_discharged": 6, "swap": None},
          {"id": "r3",  "time_to_discharged": 2, "swap": None}, 
          {"id": "r4",  "time_to_discharged": 9, "swap": None}]

ref_time =  datetime.datetime.strptime("2021-05-27 17:29:18", "%Y-%m-%d %H:%M:%S")
s.is_possible_create_first_cycle(robots, ref_time)
planner = s.SwapPlanner()
planner.start_swaps_time = ref_time
planner.create_plan(240, robots)

print("valid plan: {}".format(planner.is_valid_plan()))
logger = s.SwapLogCreator(planner.plan)
logger.create_swap_gant(log_folder_name)
logger.create_robots_swap_gant(log_folder_name)
logger.create_next_swaps_diff(log_folder_name)
# Out:
# Roboty rozładują się zanim nastąpi wymiana
# 1. Wymiany pokrywają się
# start swap time: 2021-05-27 17:31:18, swap time[min]: 3, robot id: r1, active swap: False
# start swap time: 2021-05-27 17:29:18, swap time[min]: 3, robot id: r3, active swap: False
# valid plan: False

# %%
# plan ok
s.FULL_BATTERY_WORKING_TIME = 15 # [min]
s.SWAP_TIME = 1 # [min]
s.STANDARD_CYCLE_TIME = s.FULL_BATTERY_WORKING_TIME - 2 # [min] standardowy czas na jaki planowane są wymiany
s.ALLOWED_CYCLE_TIME = s.FULL_BATTERY_WORKING_TIME - 1 # [min] pozwala na dłuższą pracę na baterii i wykonanie
# późniejszej wymiany, aby ustabilizować wymiany w równych odstępach czasowych

robots = [{"id": "r1",  "time_to_discharged": 4, "swap": None}, 
          {"id": "r2",  "time_to_discharged": 6, "swap": None},
          {"id": "r3",  "time_to_discharged": 2, "swap": None}, 
          {"id": "r4",  "time_to_discharged": 9, "swap": None}]

ref_time =  datetime.datetime.strptime("2021-05-27 17:29:18", "%Y-%m-%d %H:%M:%S")
s.is_possible_create_first_cycle(robots, ref_time)
planner = s.SwapPlanner()
planner.start_swaps_time = ref_time
planner.create_plan(240, robots)

print("valid plan: {}".format(planner.is_valid_plan()))
logger = s.SwapLogCreator(planner.plan)
logger.create_swap_gant(log_folder_name)
logger.create_robots_swap_gant(log_folder_name)
logger.create_next_swaps_diff(log_folder_name)
# Out:
# Ułożenie pierwszego cyklu wymian jest możliwe.
# valid plan: True

# %%
# plan ok
# 1 wymiana baterii jest w trakcie wykonywania, zadanie wymiany baterii trwa już 1 minutę
s.FULL_BATTERY_WORKING_TIME = 15 # [min]
s.SWAP_TIME = 2 # [min]
s.STANDARD_CYCLE_TIME = s.FULL_BATTERY_WORKING_TIME - 2 # [min] standardowy czas na jaki planowane są wymiany
s.ALLOWED_CYCLE_TIME = s.FULL_BATTERY_WORKING_TIME - 1 # [min] pozwala na dłuższą pracę na baterii i wykonanie
# późniejszej wymiany, aby ustabilizować wymiany w równych odstępach czasowych

robots = [{"id": "r1",  "time_to_discharged": 4, "swap": None}, 
          {"id": "r2",  "time_to_discharged": 6, "swap": None},
          {"id": "r3",  "time_to_discharged": 2, "swap": {"start_swap": "2021-05-27 17:28:18",
               "swap_time": s.SWAP_TIME}}, 
          {"id": "r4",  "time_to_discharged": 9, "swap": None}]

start_time = datetime.datetime.strptime("2021-05-27 17:29:18", "%Y-%m-%d %H:%M:%S")
s.is_possible_create_first_cycle(robots, start_time)
planner = s.SwapPlanner()
planner.start_swaps_time = start_time
planner.create_plan(240, robots)

print("valid plan: {}".format(planner.is_valid_plan()))
logger = s.SwapLogCreator(planner.plan)
logger.create_swap_gant(log_folder_name)
logger.create_robots_swap_gant(log_folder_name)
logger.create_next_swaps_diff(log_folder_name)
# Out:
# Ułożenie pierwszego cyklu wymian jest możliwe.
# 2. Kolejna wymiana baterii nie odbywa się przed końcem czasu pracy na pełnej baterii.
# valid plan: False

# %%
import swap_planner as s
import datetime
log_folder_name = "test_name"

# %%
# plan ok - pokrywające się wymiany dozwolone są przy inicjalizacji
# 2 wymiany baterii są w trakcie wykonywania
s.FULL_BATTERY_WORKING_TIME = 15 # [min]
s.SWAP_TIME = 2 # [min]
s.STANDARD_CYCLE_TIME = s.FULL_BATTERY_WORKING_TIME - 2 # [min] standardowy czas na jaki planowane są wymiany
s.ALLOWED_CYCLE_TIME = s.FULL_BATTERY_WORKING_TIME - 1 # [min] pozwala na dłuższą pracę na baterii i wykonanie
# późniejszej wymiany, aby ustabilizować wymiany w równych odstępach czasowych

robots = [{"id": "r1",  "time_to_discharged": 4, "swap": {"start_swap": "2021-05-27 17:28:58",
               "swap_time": s.SWAP_TIME}}, 
          {"id": "r2",  "time_to_discharged": 6, "swap": None},
          {"id": "r3",  "time_to_discharged": 2, "swap": {"start_swap": "2021-05-27 17:28:18",
               "swap_time": s.SWAP_TIME}}, 
          {"id": "r4",  "time_to_discharged": 9, "swap": None}]

ref_time =  datetime.datetime.strptime("2021-05-27 17:29:18", "%Y-%m-%d %H:%M:%S")
s.is_possible_create_first_cycle(robots, ref_time)
planner = s.SwapPlanner()
planner.start_swaps_time = ref_time
# planner.create_plan(240, robots)
planner.create_plan(30, robots)

print("valid plan: {}".format(planner.is_valid_plan()))
logger = s.SwapLogCreator(planner.plan)
logger.create_swap_gant(log_folder_name)
logger.create_robots_swap_gant(log_folder_name)
logger.create_next_swaps_diff(log_folder_name)
# Out:
# Ułożenie pierwszego cyklu wymian jest możliwe.
# 1. Wymiany pokrywają się
# start swap time: 2021-05-27 17:29:18, swap time[min]: 2, robot id: r3, active swap: False
# start swap time: 2021-05-27 17:28:58, swap time[min]: 2, robot id: r1, active swap: False
# valid plan: False

# %%
# plan błędny
# po rozruchu baterie wymianene są jedna za drugą w cyklu. Brak przerwy między kolejnymi wymianami
s.FULL_BATTERY_WORKING_TIME = 15 # [min]
s.SWAP_TIME = 3 # [min]
s.STANDARD_CYCLE_TIME = s.FULL_BATTERY_WORKING_TIME - 3 # [min] standardowy czas na jaki planowane są wymiany
s.ALLOWED_CYCLE_TIME = s.FULL_BATTERY_WORKING_TIME - 1 # [min] pozwala na dłuższą pracę na baterii i wykonanie
# późniejszej wymiany, aby ustabilizować wymiany w równych odstępach czasowych

robots = [{"id": "r1",  "time_to_discharged": 4, "swap": None}, 
          {"id": "r2",  "time_to_discharged": 6, "swap": None},
          {"id": "r3",  "time_to_discharged": 2, "swap": None}, 
          {"id": "r4",  "time_to_discharged": 9, "swap": None}]

ref_time =  datetime.datetime.strptime("2021-05-27 17:29:18", "%Y-%m-%d %H:%M:%S")
s.is_possible_create_first_cycle(robots, ref_time)
planner = s.SwapPlanner()
planner.start_swaps_time = ref_time
planner.create_plan(240, robots)

print("valid plan: {}".format(planner.is_valid_plan()))
logger = s.SwapLogCreator(planner.plan)
logger.create_swap_gant(log_folder_name)
logger.create_robots_swap_gant(log_folder_name)
logger.create_next_swaps_diff(log_folder_name)
# Out:
# Roboty rozładują się zanim nastąpi wymiana
# 1. Wymiany pokrywają się
# start swap time: 2021-05-27 17:31:18, swap time[min]: 3, robot id: r1, active swap: False
# start swap time: 2021-05-27 17:29:18, swap time[min]: 3, robot id: r3, active swap: False
# valid plan: False

# %%
a = 17.9
b = 112.9

# %%
a/b
# Out:
# 0.15854738706820193

# %%
import math
math.degrees(math.asin(a/b))
# Out:
# 9.1225914272651
